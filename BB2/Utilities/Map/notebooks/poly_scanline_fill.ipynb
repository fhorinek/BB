# %%
# %matplotlib
import matplotlib.patches as patches
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.animation as animation
import math
from operator import itemgetter
# Out:
# Using matplotlib backend: TkAgg

# %%
def get_all_edges(points):
    all_edges = []
    p = points[:-1]

    y_min, y_max, x_val, x_max, slope = 0, 0, 0, 0, 0
    #sklon 1 / m

    for i in range(0, len(points) - 1):
        if (points[i][1] < points[i + 1][1]):
            y_min = points[i][1]
            x_val = points[i][0]
            y_max = points[i + 1][1]
        else:
            y_min = points[i + 1][1]
            x_val = points[i + 1][0]
            y_max = points[i][1]
        
        x_max = max(points[i][0], points[i+1][0])

        if (y_max != y_min):
            slope = (points[i + 1][0] - points[i][0])/(points[i + 1][1] - points[i][1])
            all_edges.append([y_min, y_max, x_val, slope])

    return all_edges

# %%
def set_global_tab(global_tab):    
    global_tab.sort(key = itemgetter(0,1,2))
    return global_tab

# %%
def set_active_tab(global_tab):    
    #nastavte riadok skenovania
    scan_line = global_tab[0][0]

    active = []
    temp = []
    i = 0

    while(i < len(global_tab)):
        if(global_tab[i][0] == scan_line):
            temp = global_tab.pop(i)
            active.append(temp[1:4])
            i -= 1
        i +=1
    return global_tab, scan_line, active

# %%
def filling_polygon(active, global_tab, scan_line):    
    lines = []

    while(active):
        mass_x = []
        # step 1
        # Drawing intersects
        for i in range(0, len(active) - 1):
            if(i % 2 == 0):
                lines.append([[int(active[i][1]) ,int(active[i+1][1])], [scan_line, scan_line]])

        # step 2    
        scan_line += 1

        # step 3    
        #asset cleanup if t_max <= scan line
        h = 0
        while(h < len(active)):
            if(active[h][0] == scan_line):
                active.pop(h)
                h -= 1
            h += 1


        # increment x val with slope
        for i in range(0, len(active)):
            active[i][1] += active[i][2]



        # step 5    
        #adding from global to asset
        temp = []
        i = 0

        while(i < len(global_tab)):
            if(global_tab[i][0] == scan_line):
                temp = global_tab.pop(i)
                active.append(temp[1:4])
                i -= 1
            i +=1


        # step 6        
        active.sort(key = itemgetter(1))

    return lines

# %%
points = []
points.append([450, 522])
points.append([450, 531])
points.append([449, 553])
points.append([455, 567])
points.append([461, 579])
points.append([470, 590])
points.append([471, 591])
points.append([471, 566])
points.append([468, 561])
points.append([466, 541])
points.append([468, 533])
points.append([464, 517])
points.append([462, 516])
points.append([459, 495])
points.append([457, 480])
points.append([452, 462])
points.append([443, 443])
points.append([433, 428])
points.append([410, 404])
points.append([404, 396])
points.append([398, 388])
points.append([397, 377])
points.append([391, 367])
points.append([388, 365])
points.append([388, 362])
points.append([379, 352])
points.append([384, 352])
points.append([390, 360])
points.append([408, 381])
points.append([427, 401])
points.append([440, 417])
points.append([469, 458])
points.append([471, 462])
points.append([471, 376])
points.append([471, 376])
points.append([467, 375])
points.append([456, 369])
points.append([448, 361])
points.append([442, 353])
points.append([439, 346])
points.append([432, 326])
points.append([419, 278])
points.append([416, 276])
points.append([415, 268])
points.append([410, 252])
points.append([405, 243])
points.append([400, 235])
points.append([387, 222])
points.append([382, 223])
points.append([383, 218])
points.append([376, 213])
points.append([363, 205])
points.append([345, 196])
points.append([331, 192])
points.append([322, 192])
points.append([318, 190])
points.append([281, 185])
points.append([237, 180])
points.append([220, 177])
points.append([206, 173])
points.append([194, 170])
points.append([167, 164])
points.append([186, 246])
points.append([178, 245])
points.append([173, 241])
points.append([160, 240])
points.append([157, 242])
points.append([155, 249])
points.append([154, 250])
points.append([154, 251])
points.append([156, 252])
points.append([164, 250])
points.append([180, 258])
points.append([186, 252])
points.append([193, 247])
points.append([200, 253])
points.append([209, 262])
points.append([242, 284])
points.append([248, 289])
points.append([247, 293])
points.append([261, 312])
points.append([255, 318])
points.append([255, 340])
points.append([257, 347])
points.append([275, 375])
points.append([301, 416])
points.append([307, 425])
points.append([311, 426])
points.append([321, 422])
points.append([322, 423])
points.append([330, 432])
points.append([342, 442])
points.append([351, 446])
points.append([369, 452])
points.append([383, 452])
points.append([421, 442])
points.append([425, 448])
points.append([432, 449])
points.append([437, 454])
points.append([442, 463])
points.append([432, 457])
points.append([441, 473])
points.append([445, 489])
points.append([449, 506])
points.append([450, 522])
points.append([348, 401])
points.append([342, 391])
points.append([347, 387])
points.append([353, 392])
points.append([357, 391])
points.append([356, 397])
points.append([368, 410])
points.append([374, 414])
points.append([372, 418])
points.append([363, 416])
points.append([357, 416])
points.append([353, 411])
points.append([348, 401])
points.append([367, 394])
points.append([362, 385])
points.append([360, 380])
points.append([360, 379])
points.append([357, 369])
points.append([352, 357])
points.append([352, 349])
points.append([356, 348])
points.append([363, 373])
points.append([369, 378])
points.append([380, 369])
points.append([384, 368])
points.append([389, 376])
points.append([393, 388])
points.append([392, 390])
points.append([382, 396])
points.append([385, 398])
points.append([389, 401])
points.append([382, 403])
points.append([368, 393])
points.append([367, 394])




all_edges = get_all_edges(points)
global_tab = set_global_tab(all_edges)
for i in range(len(global_tab)):
    print(i, global_tab[i])
global_tab, scan_line, active = set_active_tab(global_tab)

print(active)
#lines = filling_polygon(active, global_tab, scan_line)


fig, ax = plt.subplots()

for i in range(0, len(points)-1):
    plt.plot((points[i][0],points[i+1][0]),(-points[i][1], -points[i+1][1]), c = 'b')
#for l in lines:
#    plt.plot(l[1], l[0], c = 'r')
# Out:
# 0 [-276, -273, -4, -0.0]
# 1 [-276, -273, -3, -0.3333333333333333]
# 2 [-276, -273, 21, -6.0]
# 3 [-276, -271, -29, 0.0]
# 4 [-273, -270, 3, -1.0]
# 5 [-271, -268, -29, -0.6666666666666666]
# 6 [-271, -262, 5, -0.6666666666666666]
# 7 [-271, -239, 11, -0.625]
# 8 [-270, -257, 0, -0.38461538461538464]
# 9 [-268, -247, -31, -0.14285714285714285]
# 10 [-262, -249, -1, -0.46153846153846156]
# 11 [-257, -249, -5, -0.25]
# 12 [-247, -220, -34, -0.4074074074074074]
# 13 [-239, -226, -9, -0.46153846153846156]
# 14 [-226, -209, -15, -0.47058823529411764]
# 15 [-220, -204, -45, -0.4375]
# 16 [-209, -192, -23, -0.47058823529411764]
# 17 [-204, -177, -52, -0.4074074074074074]
# 18 [-192, -175, -31, -0.4117647058823529]
# 19 [-177, -163, -63, -0.14285714285714285]
# 20 [-175, -163, -38, -0.25]
# 21 [-163, -161, -65, -2.5]
# 22 [-163, -143, -41, -0.05]
# 23 [-161, -121, -70, 0.225]
# 24 [-144, -143, -36, -1.0]
# 25 [-144, -128, -36, 1.0625]
# 26 [-143, -127, -37, 1.0625]
# ...
